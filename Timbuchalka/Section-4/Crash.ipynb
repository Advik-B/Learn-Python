# %%
print ("Don`t type in words")
inp = (input("First Number--\t\t"))
inp2 = (input("Second Number--\t\t"))

if (inp==str) or (inp2 == str):
  print ("Please Don`t type in words")
  endkey = input ("Press enter to exit")
else:
  
  if int(inp) <= 0 or int(inp2) <=0:
    print ("the numbers must not be less than 10")
    endkey = input ("Press enter to exit") 

  elif int(inp) < 10 or int(inp2) < 10:
    print ("Too small.The number must ")
    endkey = input ("Press enter to exit")
  else:

    print ("Are you shure you want to crash the server [Y/N]")
    print ("(if you press Y then some random numbers will be displayed, don`t worry about it)")
    caution = input ()
    if ("Y" in (caution)) or ("y" in (caution)):
      for crash in range (int(inp,int(inp2))):
        print (crash**crash)
        print ("to the power of itself is {0}".format(crash**crash**crash) ) 

      endkey = input ("Wow you computer is good congrats. press enter to exit\t\t")
    else:
      print ("Good choice your computer will thank you")
      endkey = input ("Press enter to exit")
else:
    print ("GG")

# %% [markdown]
# line 18 is not working. please fix it nana
# ![Dad.jpg](data:image/jpeg;base64,...)
